# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df=pd.read_csv("churn.csv")
print(df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df.isnull().sum()
df.dropna(inplace=True)

# %%
df = df.drop(columns=['customerID'])

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df.dropna(inplace=True)

# %%
df['OnlineSecurity'] = df['OnlineSecurity'].replace('No internet service', 'No')
df['TechSupport'] = df['TechSupport'].replace('No internet service', 'No')
df = df[['tenure', 'MonthlyCharges', 'TotalCharges',
         'Contract', 'InternetService', 'OnlineSecurity',
         'TechSupport', 'Churn']]

# %%
df = pd.get_dummies(df, columns=['Contract', 'InternetService', 'OnlineSecurity', 'TechSupport'], drop_first=True)

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']

# %%
print(df.columns)
# Out:
# Index(['tenure', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'Contract_One year', 'Contract_Two year', 'InternetService_Fiber optic',
#        'InternetService_No', 'OnlineSecurity_Yes', 'TechSupport_Yes'],
#       dtype='object')

# %%
le = LabelEncoder()
df['Churn'] = le.fit_transform(df['Churn'])

# %%
sns.countplot(x='Churn', data=df)
plt.show()

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(df.dtypes)
# Out:
# tenure                           int64
# MonthlyCharges                 float64
# TotalCharges                   float64
# Churn                            int64
# Contract_One year                 bool
# Contract_Two year                 bool
# InternetService_Fiber optic       bool
# InternetService_No                bool
# OnlineSecurity_Yes                bool
# TechSupport_Yes                   bool
# dtype: object

# %%
X = df.drop(columns=['Churn'])
y = df['Churn']

# %%
categorical_cols = X.select_dtypes(include=['object', 'string']).columns

numeric_cols = X.select_dtypes(exclude=['object']).columns

print("Categorical:", categorical_cols)
print("Numeric:", numeric_cols)
# Out:
# Categorical: Index([], dtype='object')
# Numeric: Index(['tenure', 'MonthlyCharges', 'TotalCharges', 'Contract_One year',
#        'Contract_Two year', 'InternetService_Fiber optic',
#        'InternetService_No', 'OnlineSecurity_Yes', 'TechSupport_Yes'],
#       dtype='object')

# %%
X_train.head()
# Out:
#       tenure  MonthlyCharges  TotalCharges  Contract_One year  \
# 4207      21           43.55       1011.50              False
# 3272       1           81.70         81.70              False
# 4699      49          106.65       5174.35              False
# 3515      17           55.50        934.15              False
# 4166      32           19.80        587.70               True
#
#       Contract_Two year  InternetService_Fiber optic  InternetService_No  \
# 4207              False                        False               False
# 3272              False                         True               False
# 4699               True                         True               False
# 3515              False                        False               False
# 4166              False                        False                True
#
#       OnlineSecurity_Yes  TechSupport_Yes
# 4207                True             True
# 3272                True            False
# 4699                True             True
# 3515                True            False
# 4166               False            False

# %%
import pandas as pd

X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

# Align columns in case train/test differ
X_train, X_test = X_train.align(X_test, join='left', axis=1, fill_value=0)

# %%
model = LogisticRegression(max_iter=5000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
print("Train accuracy:", model.score(X_train, y_train))
print("Test accuracy:", model.score(X_test, y_test))
# Out:
# Train accuracy: 0.7953777777777777
# Test accuracy: 0.7974413646055437

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(
    n_estimators=150,
    max_depth=8,
    min_samples_split=10,
    min_samples_leaf=5,
    class_weight='balanced',
    random_state=42
)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=8, min_samples_leaf=5,
#                        min_samples_split=10, n_estimators=150, random_state=42)

# %%
print("Train Accuracy:", rf_model.score(X_train, y_train))
print("Test Accuracy:", rf_model.score(X_test, y_test))
# Out:
# Train Accuracy: 0.7891555555555556
# Test Accuracy: 0.7491115849324804

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# [[795 264]
#  [ 89 259]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82      1059
#            1       0.50      0.74      0.59       348
#
#     accuracy                           0.75      1407
#    macro avg       0.70      0.75      0.71      1407
# weighted avg       0.80      0.75      0.76      1407

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from xgboost) (2.4.3)
# Requirement already satisfied: scipy in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from xgboost) (1.17.1)

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=5,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
print("Train Accuracy:", xgb.score(X_train, y_train))
print("Test Accuracy:", xgb.score(X_test, y_test))
# Out:
# Train Accuracy: 0.8506666666666667
# Test Accuracy: 0.7882018479033405

# %%
import pickle

# Save your trained model
pickle.dump(xgb, open("model.pkl", "wb"))

# %%
model = pickle.load(open("model.pkl", "rb"))

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (2.4.3)
# Requirement already satisfied: packaging>=20 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (6.33.6)
# Requirement already satisfied: pyarrow>=7.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (6.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.1)
# Requirement already satisfied: colorama in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in C:\Users\yaswa\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
